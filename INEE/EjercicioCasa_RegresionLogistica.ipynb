# %% [markdown]
# # Ejercicios de casa: Regresión Logística

# %%
# Instala dependencias
# !wget https://github.com/renatoparedes/EstadisticaYPsicologiaMatematica/raw/main/INEE/BaseEjerciciosRegresionLogistica.sav
# !pip install pingouin
# !pip install pyreadstat

# %%
import pandas as pd

df = pd.read_spss("BaseEjerciciosRegresionLogistica.sav")
df
# Out:
#    Código    Sexo  Edad ProbSueño  Estrés  Ansiedad  Depresión
# 0     001   Mujer  40.0        Sí     5.0       7.0        3.0
# 1     002  Hombre  26.0        Sí     8.0       6.0        1.0
# 2     003  Hombre  19.0        No     2.0       3.0        1.0
# 3     004  Hombre  35.0        No     2.0       1.0        2.0
# 4     005  Hombre  35.0        No     8.0       2.0        5.0
# ..    ...     ...   ...       ...     ...       ...        ...
# 95    096   Mujer  29.0        Sí     6.0       6.0        3.0
# 96    097   Mujer  39.0        No     6.0       4.0        0.0
# 97    098   Mujer  43.0        Sí     7.0      12.0       11.0
# 98    099  Hombre  30.0        Sí     7.0      14.0        9.0
# 99    100  Hombre  32.0        Sí     6.0       6.0        3.0
#
# [100 rows x 7 columns]

# %% [markdown]
# ## Ejercicio 1
#
# Un grupo de investigadores ha realizado un estudio sobre los factores de la violencia que influyen en la ocurrencia de un consumo de alcohol problemático en adultas y adultos de Lima. Tras una exhaustiva revisión teórica, los investigadores tienen la hipótesis de que el abuso psicológico, abuso físico y la violencia de pareja, percibida, predicen una mayor probabilidad de que ocurra este tipo de consumo. Asimismo, creen que, específicamente, el abuso psicológico es el predictor de mayor importancia.
#
# a) Plantea la hipótesis de trabajo y las hipótesis estadísticas correspondientes y señala la ecuación del modelo.
#
# b) Evalúa el funcionamiento general del modelo: ajuste y capacidad predictiva.
#
# c) Realiza los contrastes correspondientes y evalúa si se cumplen las hipótesis planteadas. Brinda una conclusión en función a las hipótesis de los investigadores.
#
# d) ¿Cuál es la variable más importante para pronosticar la ocurrencia de un consumo de alcohol problemático?

# %% [markdown]
# ## Ejercicio 2
#
# Un estudio sobre las relaciones de pareja en jóvenes tiene como objetivo principal analizar las variables psicológicas que pueden predecir que se produzca la separación de la pareja. De acuerdo a la revisión de evidencias, se espera que las personas que presentan violencia de pareja en su relación tengan mayor probabilidad de separarse de su pareja y que la relación sea inversa en el caso de las y los jóvenes que muestran mayor satisfacción en su relación de pareja. Respecto a la edad, no se tiene una hipótesis previa.
#
# a) Plantea la hipótesis de trabajo, las hipótesis estadísticas correspondientes y señala la ecuación del modelo.
#
# b) Evalúa el funcionamiento general del modelo: ajuste y capacidad predictiva.
#
# c) Realiza los contrastes correspondientes y evalúa si se cumplen las hipótesis. Brinda una conclusión en función a la hipótesis de trabajo.
#
# d) ¿Cuál es la variable más importante para pronosticar que se produzca la separación de la pareja en los y las jóvenes?
