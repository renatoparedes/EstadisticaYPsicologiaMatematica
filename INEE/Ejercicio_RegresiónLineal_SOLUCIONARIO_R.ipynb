# %% [markdown]
# # Ejercicios: Regresión Lineal Simple

# %%
install.packages("tidyverse")
install.packages("rstatix")
install.packages("psych")
install.packages("e1071")
install.packages("skimr")
install.packages("ggpubr")

library(tidyverse)
library(rstatix)
library(psych)
library(e1071)
library(skimr)
library(ggpubr)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘textshaping’, ‘ragg’
#
#
# Warning message in install.packages("tidyverse"):
# “installation of package ‘textshaping’ had non-zero exit status”
# Warning message in install.packages("tidyverse"):
# “installation of package ‘ragg’ had non-zero exit status”
# Warning message in install.packages("tidyverse"):
# “installation of package ‘tidyverse’ had non-zero exit status”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
df = haven::read_sav("https://github.com/renatoparedes/EstadisticaYPsicologiaMatematica/raw/main/INEE/Clase10_BaseRegresionLinealSimple.sav")
df
# Out:
#     Participante Horas_Internet Impulsividad Rendimiento
# 1   001           9.1925851     14.016679     5.130105
# 2   002           4.4173298     15.308135     2.493590
# 3   003           8.9703907      9.383734     3.090073
# 4   004          10.6271423     17.714813     8.166904
# 5   005           3.2295466     15.691327     6.117007
# 6   006           6.9243390     22.083637     4.756536
# 7   007          11.2960200     14.162169     6.686044
# 8   008          12.6609760     22.927041     6.639944
# 9   009           6.9810690     13.014680     5.085130
# 10  010          10.6982375     22.574243     9.079773
# 11  011          10.8124794      6.351464    10.970667
# 12  012           8.6491853     15.481772     3.125794
# 13  013           6.8301921     17.127172     3.572160
# 14  014           9.4140396     19.496756     9.647672
# 15  015           4.1752155     21.156154     5.259386
# 16  016           2.9048690     10.580515     9.023794
# 17  017           5.1111746     17.592784    11.930117
# 18  018          12.1738669     15.179294     8.800466
# 19  019           0.6706917     20.973363     5.813739
# 20  020           3.3844359     18.426478     6.940065
# 21  021           9.6487376     18.055029     8.103515
# 22  022           6.8514061      9.783338     5.802000
# 23  023           4.7037374     17.783169     6.207663
# 24  024           6.4705822      6.472533     3.077936
# 25  025           6.6327741      7.534477     4.523246
# 26  026           7.8782662      9.040469     2.582951
# 27  027           6.6530107     10.431228     8.743948
# 28  028          11.2538869      4.401401     2.413481
# 29  029          10.3531934     22.540330    -1.437135
# 30  030           7.5801800     21.059242     6.352346
# ⋮   ⋮            ⋮              ⋮            ⋮
# 121 121           8.036555      10.186848     6.77426426
# 122 122           4.778759      18.601467     7.44045783
# 123 123           5.573212      23.842839     9.03550929
# 124 124           5.190393       9.839304     9.90798627
# 125 125           6.654901      12.647669    10.92135353
# 126 126           5.693387      13.317232     3.48160248
# 127 127           7.892961       7.029692     3.66106469
# 128 128          -1.621162      12.844141     8.01486137
# 129 129           9.317839      14.583923     7.43966275
# 130 130           6.882829      21.201446     5.56293599
# 131 131           2.776825      18.327444    -0.00121225
# 132 132           8.919730       8.050315     3.06520204
# 133 133           5.549511      22.409405     4.18607177
# 134 134          10.162571      16.297479     5.36113511
# 135 135           2.931389       4.706061     2.85891183
# 136 136           8.815780      16.425436     3.08313379
# 137 137          15.161153      23.101606     3.20897575
# 138 138           7.241903       2.837210    11.67430094
# 139 139           8.376195      11.055825     3.86940884
# 140 140           5.322411      12.860413     6.52848593
# 141 141           9.845453      14.241486     1.42413849
# 142 142           6.326228       8.009949     5.91575217
# 143 143          11.418167       8.867099     8.26440263
# 144 144           7.782211      11.779555     7.55237532
# 145 145           5.634834       5.743814     8.12714285
# 146 146          14.096435       4.020885     6.03440098
# 147 147           2.494416       7.473597     2.01790605
# 148 148           1.819807      14.073889     4.75285269
# 149 149           9.772035       4.109418     5.96889026
# 150 150           4.993299      10.381116     6.87151280
#     Uso_patológico_internet Uso_problemático_celular Juego_patológico
# 1   29.979415               33.466436                51.629069
# 2    7.798216               29.608270                58.572777
# 3   79.417020               17.480083                 7.207902
# 4   77.924891               49.801048                68.254753
# 5   24.903253               38.303082                34.883736
# 6   61.594703               46.584108                30.418557
# 7   83.992027               33.738549                62.581598
# 8   86.420525               59.746719                16.617752
# 9   61.863693               28.362086                29.797933
# 10  70.976950               53.938486                74.052666
# 11  70.262625               20.133003                76.706401
# 12  77.250218               33.076556                30.774135
# 13  37.479342               58.955645                29.104039
# 14  72.648208               53.253267                62.105512
# 15  11.839689               41.025690                24.332324
# 16   5.478786               18.255311                32.508577
# 17  54.222505               29.435471                76.922575
# 18  79.838273               39.752094                63.548819
# 19   6.809212               58.802951                44.556582
# 20  51.507759               58.591159                51.012985
# 21  52.897763               35.985352                69.102566
# 22  36.179800               26.329292                20.578676
# 23  12.636629               41.374096                66.969438
# 24  45.140256                7.352425                29.043023
# 25  48.935961               18.764331                64.367974
# 26  69.325876               19.101499                30.720159
# 27  30.702795               33.794118                75.130083
# 28  92.637116               13.871256                11.639278
# 29  82.952413               45.403560                 8.242274
# 30  79.241896               52.804073                37.831322
# ⋮   ⋮                       ⋮                        ⋮
# 121 51.119868                8.577082                60.287730
# 122  7.238131               45.162074                50.442003
# 123 61.312275               57.292315                76.359361
# 124 46.159991               13.045829                40.269964
# 125 22.172240               40.680329                72.068076
# 126 27.788321               24.938622                49.168582
# 127 63.221986                8.495901                19.142359
# 128 11.307842               30.375585                76.893332
# 129 80.018310               35.600017                59.880585
# 130 39.710442               38.607496                52.840327
# 131 15.822349               48.244486                16.394456
# 132 49.367575               26.108883                41.714388
# 133 29.514417               59.873830                34.315376
# 134 62.631335               41.741620                41.360544
# 135 13.139354               12.674204                28.631733
# 136 55.505926               42.965074                14.948901
# 137 94.952216               58.680601                22.737774
# 138 68.588022               15.231204                77.487363
# 139 73.824767               28.281495                16.362121
# 140 26.575965               21.205260                31.829500
# 141 65.454068               37.805021                13.929502
# 142 20.052276                5.186251                 7.633245
# 143 72.800438               10.786748                54.035043
# 144 47.531411               26.866018                71.178203
# 145 48.487135               10.696233                30.663718
# 146 74.495379               13.452317                21.921853
# 147 20.563357               32.106987                29.550263
# 148 12.366920               37.269633                50.269255
# 149 84.842823               17.856490                74.436065
# 150 83.103930               15.067667                36.106814

# %% [markdown]
# ### Analiza las siguientes hipótesis de estudio:

# %% [markdown]
# HT1: El uso patológico de internet predice la cantidad de horas que los estudiantes navegan en internet.
# - Variable predictora (X) = Uso patológico del internet (PI)
# - Variable de saluda (Y) = Cantidad de horas navegando en inernet  (HI)
#
# $H_{0}: \beta_{PI} = 0$ vs $H_{1}: \beta_{PI} \ne 0$
#
# **Ecuación del modelo**
#
# $Y = \beta_{0} + \beta_{x}X_{x} \pm \epsilon ⇒ HI = \beta_{PI}X_{PI} \pm ϵ,$ con $\beta_{PI} \ne 0$

# %% [markdown]
# Gráfico de dispersión de puntos

# %%
df |> 
  ggplot(aes(x = Uso_patológico_internet, y = Horas_Internet)) + 
  geom_point() +
  geom_smooth(method = lm) +
  labs(x = "Uso patológico del internet",
       y = "Horas navegando en Internet") +
  theme_minimal()
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %% [markdown]
# A partir del gráfico, se observa una posible tendencia lineal positiva entre las variables, de modo que a mayor uso patológico de internet, una posible mayor cantidad de horas en Internet.

# %% [markdown]
# Prueba de normalidad

# %%
df |> 
  shapiro_test(Uso_patológico_internet, Horas_Internet) |> 
  mutate(normal = case_when(p < .05 ~ F, T ~ T))
# Out:
#   variable                statistic p            normal
# 1 Horas_Internet          0.9914451 0.5041663886  TRUE
# 2 Uso_patológico_internet 0.9474026 0.0000200496 FALSE

# %% [markdown]
# Hipótesis Estadísticas
#
# $H_{0} =$ la distribución de los grupos es normal
#
# $H_{1} =$ la distribución de los grupos no es normal
#
# A partir de la prueba de normalidad de Shapiro Wilk, se observa que si bien la cantidad de horas en internet tiene una distribución normal,$SW_{(150)} = .99, p = .50$, el uso patológico del internet presenta ciertos problemas de simetría, $SW_{(150)} = .95, p < .001$. Por todo ello, se realizará un análisis de correlación de Spearman.

# %% [markdown]
# Análisis de correlación

# %%
df |> 
  select(Uso_patológico_internet, Horas_Internet) |> 
  psych::corr.test(method = "spearman")
# Out:
# Warning message in abbreviate(rownames(r), minlength = minlength):
# “abbreviate used with non-ASCII chars”
# Warning message in abbreviate(colnames(r), minlength = minlength):
# “abbreviate used with non-ASCII chars”
# Warning message in abbreviate(dimnames(ans)[[2L]], minlength = abbr.colnames):
# “abbreviate used with non-ASCII chars”
# Call:psych::corr.test(x = select(df, Uso_patológico_internet, Horas_Internet),
#     method = "spearman")
# Correlation matrix
#                         Uso_patológico_internet Horas_Internet
# Uso_patológico_internet                     1.0            0.8
# Horas_Internet                              0.8            1.0
# Sample Size
# [1] 150
# Probability values (Entries above the diagonal are adjusted for multiple tests.)
#                         Uso_patológico_internet Horas_Internet
# Uso_patológico_internet                       0              0
# Horas_Internet                                0              0
#
#  To see confidence intervals of the correlations, print with the short=FALSE option

# %% [markdown]
# A partir del análisis de correlación de Spearman, se observa que existe una relación estadísticamente signifiativa, positiva y grande, según el criterio de Cohen(1988), entre el uso patológico del internet y la cantidad de horas que se emplea en navegar por internet, $r_{(148)} = .8, p < .001$.

# %% [markdown]
# Supuesto de residuos estandarizados

# %%
df %>%
  lm("Horas_Internet ~ Uso_patológico_internet", data = .) -> model

# %%
tibble(residuals = model$residuals) |> 
  ggpubr::ggqqplot(x = "residuals")
# Out:
# plot without title

# %% [markdown]
# El QQ-Plot parece indicar que la mayoría de puntos se encuentran en la línea, sin embargo, un número importante de puntos en los extremos se encuentran lejos de la misma.

# %%
model$residuals |> 
  shapiro_test()
# Out:
#   variable        statistic p.value
# 1 model$residuals 0.9857956 0.1273353

# %% [markdown]
# $H_{0} =$ la distribución de los grupos es normal
#
# $H_{1} =$ la distribución de los grupos no es normal
#
# A partir de la prueba de normalidad de Shapiro-Wilk, se observa que la distribución de los residuos del modelo es normal, $SW_{(150)} = .986, p = .127$.

# %% [markdown]
# Evaluar el modelo

# %%
model |> summary()
# Out:
# Call:
# lm(formula = "Horas_Internet ~ Uso_patológico_internet", data = .)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.4511 -1.1944  0.0056  1.5738  4.6174
#
# Coefficients:
#                         Estimate Std. Error t value Pr(>|t|)
# (Intercept)             1.831240   0.342985   5.339 3.44e-07 ***
# Uso_patológico_internet 0.102661   0.006452  15.912  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.055 on 148 degrees of freedom
# Multiple R-squared:  0.6311,	Adjusted R-squared:  0.6286
# F-statistic: 253.2 on 1 and 148 DF,  p-value: < 2.2e-16

# %% [markdown]
# Hipótesis Estadísticas
#
# $H_{0}: \beta_{PI} = 0$ vs $H_{1}: \beta_{PI} \ne 0$
#
# Se acepta H1 y se rechaza H0 dado que el valor p es menor a .05.
#
# A partir del análisis de regresión lineal simple, se observa que existe un modelo grande, según el criterio de Cohen (1988), y adecuado del uso patológico del internet como predictor de la cantidad de horas que se pasan en esta plataforma, $R^{2} = .63, F_{(1, 148)} = 253.2, p < .001$. Espcíficamente, se encontró que el uso patológico es un predictor positivo de la cantidad de horas, $\beta_{PI} = .103, EE_{b} = .01, t_{(148)} = 15.912, p < .001$. Por todo ello, se cumple con las hipótesis de los investigadores.
#
# Ecuación del modelo
#
# $CH = 1.83 + .10(PI) \pm 2.055$

# %% [markdown]
# HT2: El uso problemático del celular disminuye el rendimiento académico (RA) de estudiantes de secundaria.

# %% [markdown]
# - Variable predictora (X) = Uso patológico del celular (PC)
# - Variable de saluda (Y) = Rendimiento Académico (RA)
#
# $H_{0}: \beta_{PC} = 0$ vs $H_{1}: \beta_{PC} < 0$
#
# **Ecuación del modelo**
#
# $Y = \beta_{0} + \beta_{x}X_{x} \pm \epsilon ⇒ RA = \beta_{PC}X_{PC} \pm ϵ,$ con $\beta_{PC} < 0$

# %% [markdown]
# Gráfico de dispersión de puntos

# %%
df |> 
  ggplot(aes(x = Uso_problemático_celular, y = Rendimiento)) + 
  geom_point() +
  geom_smooth(method = lm) +
  labs(x = "Uso problemático del celular",
       y = "Rendimiento Académico") +
  theme_minimal()
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %% [markdown]
# A partir del gráfico, se observa una posible relación nula entre las variables, dado que la tendencia de la pendiente no se posiciona para un lado o para el otro.

# %% [markdown]
# Prueba de normalidad

# %%
df |> 
  shapiro_test(Uso_problemático_celular, Rendimiento) |> 
  mutate(normal = case_when(p < .05 ~ F, T ~ T))
# Out:
#   variable                 statistic p            normal
# 1 Rendimiento              0.9949506 0.8860314674  TRUE
# 2 Uso_problemático_celular 0.9591323 0.0002039892 FALSE

# %% [markdown]
# Hipótesis Estadísticas
#
# $H_{0} =$ la distribución de los grupos es normal
#
# $H_{1} =$ la distribución de los grupos no es normal
#
# A partir de la prueba de normalidad de Shapiro Wilk, se observa que si bien el rendimiento tiene una distribución normal,$SW_{(150)} = .99, p = .89$, el uso patológico del celular presenta ciertos problemas de simetría, $SW_{(150)} = .96, p < .001$. Por todo ello, se realizará un análisis de correlación de Spearman.

# %% [markdown]
# Análisis de correlación

# %%
df |> 
  select(Uso_problemático_celular, Rendimiento) |> 
  psych::corr.test(method = "spearman")
# Out:
# Warning message in abbreviate(rownames(r), minlength = minlength):
# “abbreviate used with non-ASCII chars”
# Warning message in abbreviate(colnames(r), minlength = minlength):
# “abbreviate used with non-ASCII chars”
# Warning message in abbreviate(dimnames(ans)[[2L]], minlength = abbr.colnames):
# “abbreviate used with non-ASCII chars”
# Call:psych::corr.test(x = select(df, Uso_problemático_celular, Rendimiento),
#     method = "spearman")
# Correlation matrix
#                          Uso_problemático_celular Rendimiento
# Uso_problemático_celular                     1.00        0.01
# Rendimiento                                  0.01        1.00
# Sample Size
# [1] 150
# Probability values (Entries above the diagonal are adjusted for multiple tests.)
#                          Uso_problemático_celular Rendimiento
# Uso_problemático_celular                     0.00        0.88
# Rendimiento                                  0.88        0.00
#
#  To see confidence intervals of the correlations, print with the short=FALSE option

# %% [markdown]
# A partir del análisis de correlación de Spearman, se observa que no existe una relación estadísticamente signifiativa entre el uso problemático del celular y el rendimiento, $r_{(148)} = .01, p = .88$.

# %% [markdown]
# Supuesto de residuos estandarizados

# %%
df %>%
  lm("Rendimiento ~ Uso_problemático_celular", data = .) -> model

# %%
tibble(residuals = model$residuals) |> 
  ggpubr::ggqqplot(x = "residuals")
# Out:
# plot without title

# %% [markdown]
# El QQ-Plot parece indicar que la mayoría de puntos se encuentran en la línea, sin embargo, algunos puntos en los extremos parecen alejarse de una distribución normal.

# %%
model$residuals |> 
  shapiro_test()
# Out:
#   variable        statistic p.value
# 1 model$residuals 0.99449   0.8432294

# %% [markdown]
# $H_{0} =$ la distribución de los grupos es normal
#
# $H_{1} =$ la distribución de los grupos no es normal
#
# A partir de la prueba de normalidad de Shapiro-Wilk, se observa que la distribución de los residuos del modelo es normal, $SW_{(150)} = .994, p = .843$.

# %% [markdown]
# Evaluar el modelo

# %%
model |> summary()
# Out:
# Call:
# lm(formula = "Rendimiento ~ Uso_problemático_celular", data = .)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -8.4599 -2.1554 -0.0443  2.0185  7.2415
#
# Coefficients:
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)              5.913551   0.561167   10.54   <2e-16 ***
# Uso_problemático_celular 0.004591   0.015852    0.29    0.773
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.957 on 148 degrees of freedom
# Multiple R-squared:  0.0005664,	Adjusted R-squared:  -0.006187
# F-statistic: 0.08387 on 1 and 148 DF,  p-value: 0.7725

# %% [markdown]
# Hipótesis Estadísticas
#
# $H_{0}: \beta_{PC} = 0$ vs $H_{1}: \beta_{PC} < 0$
#
# Se acepta H0 dado que el valor p unilateral (.773/2 = .387)es mayor a .05.
#
# A partir del análisis de regresión lineal simple, se observa que no xiste un modelo adecuado del uso patológico del celular como predictor del rendimiento académico, $R^{2} = .00, F_{(1, 148)} = .084, p = .387$.

# %% [markdown]
# HT3: El juego patológico aumenta el nivel de impulsividad de estudiantes de secundaria.

# %% [markdown]
# - Variable predictora (X) = Juego Patológico (JP)
# - Variable de saluda (Y) = Impulsividad (IM)
#
# $H_{0}: \beta_{JP} = 0$ vs $H_{1}: \beta_{JP} > 0$
#
# **Ecuación del modelo**
#
# $Y = \beta_{0} + \beta_{x}X_{x} \pm \epsilon ⇒ IM = \beta_{JP}X_{JP} \pm ϵ,$ con $\beta_{JP} > 0$

# %% [markdown]
# Gráfico de dispersión de puntos

# %%
df |> 
  ggplot(aes(x = Juego_patológico, y = Impulsividad)) + 
  geom_point() +
  geom_smooth(method = lm) +
  labs(x = "Juego Patológico",
       y = "Impulsividad") +
  theme_minimal()
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %% [markdown]
# A partir del gráfico de dispersión de puntos, se observa una leve tendencia a una relación positiva. No obstante, es posible que la relación sea nula.

# %% [markdown]
# Prueba de normalidad

# %%
df |> 
  shapiro_test(Juego_patológico, Impulsividad) |> 
  mutate(normal = case_when(p < .05 ~ F, T ~ T))
# Out:
#   variable         statistic p            normal
# 1 Impulsividad     0.9743426 6.577670e-03 FALSE
# 2 Juego_patológico 0.9521213 4.934017e-05 FALSE

# %% [markdown]
# Hipótesis Estadísticas
#
# $H_{0} =$ la distribución de los grupos es normal
#
# $H_{1} =$ la distribución de los grupos no es normal
#
# A partir de la prueba de normalidad de Shapiro Wilk, se observa que tanto la impulsividad, $SW_{(150)} = .97, p = .007$, y el juego patológico presentan una distribución no normal, $SW_{(150)} = .95, p < .001$. Por todo ello, se realizará un análisis de correlación de Spearman.

# %% [markdown]
# Análisis de correlación

# %%
df |> 
  select(Juego_patológico, Impulsividad) |> 
  psych::corr.test(method = "spearman")
# Out:
# Warning message in abbreviate(rownames(r), minlength = minlength):
# “abbreviate used with non-ASCII chars”
# Warning message in abbreviate(colnames(r), minlength = minlength):
# “abbreviate used with non-ASCII chars”
# Warning message in abbreviate(dimnames(ans)[[2L]], minlength = abbr.colnames):
# “abbreviate used with non-ASCII chars”
# Call:psych::corr.test(x = select(df, Juego_patológico, Impulsividad),
#     method = "spearman")
# Correlation matrix
#                  Juego_patológico Impulsividad
# Juego_patológico             1.00         0.08
# Impulsividad                 0.08         1.00
# Sample Size
# [1] 150
# Probability values (Entries above the diagonal are adjusted for multiple tests.)
#                  Juego_patológico Impulsividad
# Juego_patológico              0.0          0.3
# Impulsividad                  0.3          0.0
#
#  To see confidence intervals of the correlations, print with the short=FALSE option

# %% [markdown]
# A partir del análisis de correlación de Spearman, se observa que no existe una relación estadísticamente signifiativa entre el juego patológico y la impulsividad, $r_{(148)} = .08, p = .30$.

# %% [markdown]
# Supuesto de residuos estandarizados

# %%
df %>%
  lm("Impulsividad ~ Juego_patológico", data = .) -> model

# %%
tibble(residuals = model$residuals) |> 
  ggpubr::ggqqplot(x = "residuals")
# Out:
# plot without title

# %% [markdown]
# A partir del gráfico de QQ, se observa cierta tendencia a seguir la distribución normal, no obstante, en los extremos se distinguen datos que se devían de una distribución gaussiana.

# %%
model$residuals |> 
  shapiro_test()
# Out:
#   variable        statistic p.value
# 1 model$residuals 0.976991  0.01278929

# %% [markdown]
# $H_{0} =$ la distribución de los grupos es normal
#
# $H_{1} =$ la distribución de los grupos no es normal
#
# A partir de la prueba de normalidad de Shapiro-Wilk, se observa que la distribución de los residuos del modelo no es normal, $SW_{(150)} = .977, p = .013$.

# %% [markdown]
# Evaluar el modelo

# %%
model |> summary()
# Out:
# Call:
# lm(formula = "Impulsividad ~ Juego_patológico", data = .)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -12.8538  -4.3128  -0.1179   4.3172  12.1422
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)      12.18219    1.11455   10.93   <2e-16 ***
# Juego_patológico  0.02140    0.02326    0.92    0.359
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 6.021 on 148 degrees of freedom
# Multiple R-squared:  0.005683,	Adjusted R-squared:  -0.001035
# F-statistic: 0.8459 on 1 and 148 DF,  p-value: 0.3592

# %% [markdown]
# Hipótesis Estadísticas
#
# $H_{0}: \beta_{JP} = 0$ vs $H_{1}: \beta_{JP} > 0$
#
# Se acepta H0 dado que el valor p unilateral (.359/2 = .18) es mayor a .05.
#
# A partir del análisis de regresión lineal simple, se observa que no existe un modelo adecuado del juego patológico como predictor de la impulsividad, $R^{2} = .01, F_{(1, 148)} = .846, p = .18$.

# %% [markdown]
# HT4: El uso problemático del celular aumenta la impulsividad reportada por estudiantes de secundaria.

# %% [markdown]
# Gráfico de dispersión de puntos

# %%
df |> 
  ggplot(aes(x = Uso_problemático_celular, y = Impulsividad)) + 
  geom_point() +
  geom_smooth(method = lm) +
  labs(x = "Uso problemático del celular",
       y = "Impulsividad") +
  theme_minimal()
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %% [markdown]
# Prueba de normalidad

# %%
df |> 
  shapiro_test(Uso_problemático_celular, Impulsividad) |> 
  mutate(normal = case_when(p < .05 ~ F, T ~ T))
# Out:
#   variable                 statistic p            normal
# 1 Impulsividad             0.9743426 0.0065776697 FALSE
# 2 Uso_problemático_celular 0.9591323 0.0002039892 FALSE

# %% [markdown]
# Análisis de correlación

# %%
df |> 
  select(Uso_problemático_celular, Impulsividad) |> 
  psych::corr.test(method = "spearman")
# Out:
# Warning message in abbreviate(rownames(r), minlength = minlength):
# “abbreviate used with non-ASCII chars”
# Warning message in abbreviate(colnames(r), minlength = minlength):
# “abbreviate used with non-ASCII chars”
# Warning message in abbreviate(dimnames(ans)[[2L]], minlength = abbr.colnames):
# “abbreviate used with non-ASCII chars”
# Call:psych::corr.test(x = select(df, Uso_problemático_celular, Impulsividad),
#     method = "spearman")
# Correlation matrix
#                          Uso_problemático_celular Impulsividad
# Uso_problemático_celular                     1.00         0.91
# Impulsividad                                 0.91         1.00
# Sample Size
# [1] 150
# Probability values (Entries above the diagonal are adjusted for multiple tests.)
#                          Uso_problemático_celular Impulsividad
# Uso_problemático_celular                        0            0
# Impulsividad                                    0            0
#
#  To see confidence intervals of the correlations, print with the short=FALSE option

# %% [markdown]
# Supuesto de residuos estandarizados

# %%
df %>%
  lm("Impulsividad ~ Uso_problemático_celular", data = .) -> model

# %%
tibble(residuals = model$residuals) |> 
  ggpubr::ggqqplot(x = "residuals")
# Out:
# plot without title

# %%
model$residuals |> 
  shapiro_test()
# Out:
#   variable        statistic p.value
# 1 model$residuals 0.9924706 0.6178825

# %% [markdown]
# Evaluar el modelo

# %%
model |> summary()
# Out:
# Call:
# lm(formula = "Impulsividad ~ Uso_problemático_celular", data = .)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.3354 -1.9062 -0.0714  1.7340  5.8431
#
# Coefficients:
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)               1.71136    0.48701   3.514 0.000586 ***
# Uso_problemático_celular  0.35645    0.01376  25.910  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.566 on 148 degrees of freedom
# Multiple R-squared:  0.8194,	Adjusted R-squared:  0.8181
# F-statistic: 671.3 on 1 and 148 DF,  p-value: < 2.2e-16

# %% [markdown]
# HT5: El juego patológico disminuye el rendimiento académico de estudiantes de secundaria.

# %%
names(df)
# Out:
# [1] "Participante"             "Horas_Internet"
# [3] "Impulsividad"             "Rendimiento"
# [5] "Uso_patológico_internet"  "Uso_problemático_celular"
# [7] "Juego_patológico"

# %% [markdown]
# Gráfico de dispersión de puntos

# %%
df |> 
  ggplot(aes(x = Juego_patológico, y = Rendimiento)) + 
  geom_point() +
  geom_smooth(method = lm) +
  labs(x = "Juego Patológico",
       y = "Rendimiento Académico") +
  theme_minimal()
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %% [markdown]
# Prueba de normalidad

# %%
df |> 
  shapiro_test(Juego_patológico, Rendimiento) |> 
  mutate(normal = case_when(p < .05 ~ F, T ~ T))
# Out:
#   variable         statistic p            normal
# 1 Juego_patológico 0.9521213 4.934017e-05 FALSE
# 2 Rendimiento      0.9949506 8.860315e-01  TRUE

# %% [markdown]
# Análisis de correlación

# %%
df |> 
  select(Juego_patológico, Rendimiento) |> 
  psych::corr.test(method = "spearman")
# Out:
# Warning message in abbreviate(rownames(r), minlength = minlength):
# “abbreviate used with non-ASCII chars”
# Warning message in abbreviate(colnames(r), minlength = minlength):
# “abbreviate used with non-ASCII chars”
# Warning message in abbreviate(dimnames(ans)[[2L]], minlength = abbr.colnames):
# “abbreviate used with non-ASCII chars”
# Call:psych::corr.test(x = select(df, Juego_patológico, Rendimiento),
#     method = "spearman")
# Correlation matrix
#                  Juego_patológico Rendimiento
# Juego_patológico             1.00        0.71
# Rendimiento                  0.71        1.00
# Sample Size
# [1] 150
# Probability values (Entries above the diagonal are adjusted for multiple tests.)
#                  Juego_patológico Rendimiento
# Juego_patológico                0           0
# Rendimiento                     0           0
#
#  To see confidence intervals of the correlations, print with the short=FALSE option

# %% [markdown]
# Supuesto de residuos estandarizados

# %%
df %>%
  lm("Rendimiento ~ Juego_patológico", data = .) -> model

# %%
tibble(residuals = model$residuals) |> 
  ggpubr::ggqqplot(x = "residuals")
# Out:
# plot without title

# %%
model$residuals |> 
  shapiro_test()
# Out:
#   variable        statistic p.value
# 1 model$residuals 0.9916676 0.5279706

# %% [markdown]
# Evaluar el modelo

# %%
model |> summary()
# Out:
# Call:
# lm(formula = "Rendimiento ~ Juego_patológico", data = .)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -5.3068 -1.3946 -0.2696  1.2942  6.4639
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)      1.872101   0.390705   4.792 3.98e-06 ***
# Juego_patológico 0.097402   0.008155  11.944  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.111 on 148 degrees of freedom
# Multiple R-squared:  0.4908,	Adjusted R-squared:  0.4874
# F-statistic: 142.7 on 1 and 148 DF,  p-value: < 2.2e-16
