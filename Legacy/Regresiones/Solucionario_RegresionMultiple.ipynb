# %% [markdown]
# # Práctica: Regresión Múltiple
#
# Eres parte de un grupo de investigación enfocado en el comportamiento social. Actualmente, tu grupo se encuentra analizando una base de datos de comportamiento antisocial en Estados unidos. Cuentas con las siguientes variables:
#
# - moralIntegration: Compuesto de la tasa de delincuencia y los gastos de bienestar.
# - heterogeneity: Heterogeneidad étnica, a partir de porcentajes de residentes no blancos y blancos nacidos en el extranjero.
# - mobility: Movilidad geográfica a partir de porcentajes de residentes que entran y salen de la ciudad.
# - region: E = Northeast, MW = Midwest, S = Southeast, W = West
#
# Para empezar, se te ha asignado la exploración de posibles variables que puedan influir en el comportamiento antisocial en las diferentes ciudades.

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

df = pd.read_csv(
    "https://socialsciences.mcmaster.ca/jfox/Books/Applied-Regression-3E/datasets/Angell.txt",
    sep=r"\s{1,}",
    engine="python",
)
angell_data = pd.get_dummies(df, drop_first=True)
angell_data
# Out:
#                 moralIntegration  heterogeneity  mobility  region_MW  \
# Rochester                   19.0           20.6      15.0          0
# Syracuse                    17.0           15.6      20.2          0
# Worcester                   16.4           22.1      13.6          0
# Erie                        16.2           14.0      14.8          0
# Milwaukee                   15.8           17.4      17.6          1
# Bridgeport                  15.3           27.9      17.5          0
# Buffalo                     15.2           22.3      14.7          0
# Dayton                      14.3           23.7      23.8          1
# Reading                     14.2           10.6      19.4          0
# DesMoines                   14.1           12.7      31.9          1
# Cleveland                   14.0           39.7      18.6          1
# Denver                      13.9           13.0      34.5          0
# Peoria                      13.8           10.7      35.1          1
# ...

# %% [markdown]
# ## Parte 1: Diseño
#
# 1. Estandariza los datos y explora las correlaciones entre las variables a través de un mapa de calor. ¿Qué observas?

# %%
# Transformacion Z
scaler = StandardScaler()
scaled_data = scaler.fit_transform(angell_data)
scaled_angell_data = pd.DataFrame(scaled_data, columns=angell_data.columns)
scaled_angell_data
# Out:
#     moralIntegration  heterogeneity  mobility  region_MW  region_S  region_W
# 0           2.209629      -0.533992 -1.302175  -0.694808 -0.694808 -0.402694
# 1           1.643057      -0.781852 -0.764670  -0.694808 -0.694808 -0.402694
# 2           1.473086      -0.459635 -1.446887  -0.694808 -0.694808 -0.402694
# 3           1.416429      -0.861166 -1.322848  -0.694808 -0.694808 -0.402694
# 4           1.303115      -0.692622 -1.033422   1.439246 -0.694808 -0.402694
# 5           1.161472      -0.172118 -1.043759  -0.694808 -0.694808 -0.402694
# 6           1.133143      -0.449720 -1.333184  -0.694808 -0.694808 -0.402694
# 7           0.878186      -0.380320 -0.392551   1.439246 -0.694808 -0.402694
# 8           0.849857      -1.029711 -0.847363  -0.694808 -0.694808 -0.402694
# 9           0.821529      -0.925610  0.444715   1.439246 -0.694808 -0.402694
# 10          0.793200       0.412830 -0.930056   1.439246 -0.694808 -0.402694
# ...

# %%
import seaborn as sns

sns.heatmap(scaled_angell_data.corr());

# %% [markdown]
# Podemos apreciar correlaciones moderadas (positivas y negativas) entre la variable moralIntegration y las demás variables.

# %% [markdown]
# 2. Implementa un modelo de regresión múltiple que tome como variable dependiente a la variable `workingMom` y como variables independientes al resto.

# %%
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms
import statsmodels.api as sm

# Fit regression model
model = smf.ols(
    "moralIntegration ~ heterogeneity + mobility + region_MW + region_S + region_W",
    data=scaled_angell_data,
).fit();

# %% [markdown]
# ## Parte 2: Verificación de supuestos

# %% [markdown]
# 3. Verifica el supuesto de homocedasticidad. En caso el supuesto no se cumpla, aplica una medida correctiva en el modelo previamente especificado.

# %%
name = ["Lagrange multiplier statistic", "p-value", "f-value", "f p-value"]
test = sms.het_breuschpagan(model.resid, model.model.exog)
list(zip(name, test))
# Out:
# [('Lagrange multiplier statistic', 1.4265218500132786),
#  ('p-value', 0.9213902318873464),
#  ('f-value', 0.25391817475588424),
#  ('f p-value', 0.9351381750848368)]

# %% [markdown]
# La prueba de Lagrange nos permite afirmar que el supuesto de homocedasticidad se cumple.

# %% [markdown]
# 4. Verifica el supuesto de normalidad. En caso el supuesto no se cumpla, aplica una medida correctiva en el modelo previamente especificado.

# %%
import pingouin as pg

pg.qqplot(model.resid);

# %%
name = ["Jarque-Bera", "Chi^2 two-tail prob.", "Skew", "Kurtosis"]
test = sms.jarque_bera(model.resid)
list(zip(name, test))
# Out:
# [('Jarque-Bera', 1.8176741004965302),
#  ('Chi^2 two-tail prob.', 0.4029926117829622),
#  ('Skew', -0.15378669925645383),
#  ('Kurtosis', 2.0408783280789975)]

# %% [markdown]
# La prueba de Jaque-Bera nos permite afirmar que el supuesto de normalidad se cumple.

# %% [markdown]
# ## Estimación y evaluación
#
# 6. Examina la significancia del modelo y su coeficiente de determinación. ¿Qué observas?

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       moralIntegration   R-squared:                       0.687
# Model:                            OLS   Adj. R-squared:                  0.645
# Method:                 Least Squares   F-statistic:                     16.27
# Date:                Wed, 03 Nov 2021   Prob (F-statistic):           1.77e-08
# Time:                        22:39:09   Log-Likelihood:                -36.013
# No. Observations:                  43   AIC:                             84.03
# Df Residuals:                      37   BIC:                             94.59
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# Podemos apreciar que el modelo de regresión es estadísticamente significativo. Es decir, su coeficiente de determinación es diferente de cero. A nivel descriptivo podemos apreciar que el modelo propuesto explica el 68% de la varianza.

# %% [markdown]
# 7. Examina la significancia de los coeficientes de regresión. ¿Puedes simplificar el modelo?

# %%
new_model = smf.ols(
    "moralIntegration ~ heterogeneity + region_MW + region_S + region_W",
    data=scaled_angell_data,
).fit()
new_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       moralIntegration   R-squared:                       0.677
# Model:                            OLS   Adj. R-squared:                  0.642
# Method:                 Least Squares   F-statistic:                     19.87
# Date:                Wed, 03 Nov 2021   Prob (F-statistic):           6.75e-09
# Time:                        22:39:09   Log-Likelihood:                -36.750
# No. Observations:                  43   AIC:                             83.50
# Df Residuals:                      38   BIC:                             92.31
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# El coeficiente de regresión de la variable `mobility` no es estadísticamente significativo. Podemos optar por retirar dicha variable del modelo, de modo que contamos con `heterogeneity` y `region` como predictores de `moralIntregration`.

# %% [markdown]
# 8. Examina las observaciones influyentes. ¿Qué observas?

# %%
fig = sm.graphics.influence_plot(new_model, criterion="cooks")
fig.tight_layout(pad=1.0)

# %% [markdown]
# Podemos apreciar que existen al menos tres observaciones influyentes que pdor[ian ser consideradas por los investigadores debido a su localización en el gráfico de influencia. Especialmente podría revisarse el caso número 40.

# %% [markdown]
# ## Interpretación
#
# 9. Examina la importancia relativa de las variables independientes. ¿Qué observas?

# %%
fig = sm.graphics.plot_partregress_grid(new_model)
fig.tight_layout(pad=1.0)
fig.set_size_inches(10, 10)

# %%
new_model.params.round(3)
# Out:
# Intercept       -0.000
# heterogeneity   -0.278
# region_MW       -0.422
# region_S        -0.826
# region_W        -0.509
# dtype: float64

# %% [markdown]
# Puede apreciarse que la pertenencia a la región sur es particularmente influyente en los puntajes de moralIntegration. Cabe resaltar que esta variable ficticia toma como línea base la pertenencia a la región norte, de modo que la pertenencia a las regiones norte-sur es particularmente influyente en el puntaje examinado.
#
# > Para más detalles sobre cómo interpretar las variables ficticias, puedes revisar estas [diapositivas](http://www.ce.memphis.edu/7012/L13_MLR_Dummy.pdf) de la Universidad de Memphis.

# %% [markdown]
# 10. Examina la multicolinealiad del modelo. ¿Qué observas?

# %%
X = pd.DataFrame(new_model.model.exog, columns=new_model.params.index)
X.corr()
# Out:
#                Intercept  heterogeneity  region_MW  region_S  region_W
# Intercept            NaN            NaN        NaN       NaN       NaN
# heterogeneity        NaN       1.000000  -0.333873  0.727215 -0.295882
# region_MW            NaN      -0.333873   1.000000 -0.482759 -0.279795
# region_S             NaN       0.727215  -0.482759  1.000000 -0.279795
# region_W             NaN      -0.295882  -0.279795 -0.279795  1.000000

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# the independent variables set
X = new_model.model.exog

# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = new_model.params.index

# calculating VIF for each feature
vif_data["VIF"] = [
    variance_inflation_factor(X, i)
    for i in range(new_model.model.exog.shape[1])
]
vif_data
# Out:
#          feature       VIF
# 0      Intercept  1.000000
# 1  heterogeneity  2.169822
# 2      region_MW  1.727351
# 3       region_S  2.707942
# 4       region_W  1.464933

# %% [markdown]
# Si bien existe una correlación especialmente fuerte entre las variables `heterogeneity` y `region_S`, el factor VIF se encuentra dentro de los rangos aceptables. Podemos concluir preliminarmente que el modelo no presenta problemas de multicolinealidad.
